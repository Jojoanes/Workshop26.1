# %% [markdown]
# # Desafio18_03
#
# > Adicionar aspas

# %%
import numpy as np
temperaturas = np.random.uniform(20, 35, 7).round(1)
dias = ['segunda', 'terça', 'quarta', 'quinta', 'sexta', 'sábado', 'domingo']
print(temperaturas)
print(dias)
# Out:
# [25.7 23.4 26.2 25.  21.5 29.7 31. ]
# ['segunda', 'terça', 'quarta', 'quinta', 'sexta', 'sábado', 'domingo']

# %%
# 2. PANDAS
import pandas as pd

df = pd.DataFrame({
    "Dia": dias,
    "Temperatura": temperaturas
})

media = df["Temperatura"].mean()
max_temp = df["Temperatura"].max()
min_temp = df["Temperatura"].min()

print(df)
print(f"\nMédia: {media:.2f}°C | Máx: {max_temp}°C | Mín: {min_temp}°C")
# Out:
#        Dia  Temperatura
# 0  segunda         25.7
# 1    terça         23.4
# 2   quarta         26.2
# 3   quinta         25.0
# 4    sexta         21.5
# 5   sábado         29.7
# 6  domingo         31.0
#
# Média: 26.07°C | Máx: 31.0°C | Mín: 21.5°C

# %%
# 3. MATPLOTLIB
import matplotlib.pyplot as plt

# 🔹 Gráfico 1
plt.figure()
plt.plot(dias, temperaturas, marker='o')
plt.title("Variação da Temperatura ")
plt.xlabel("Dias")
plt.ylabel("Temperatura (°C)")
plt.grid()
plt.show()

# %%
# 🔹 Gráfico 2
plt.figure()
plt.bar(dias, temperaturas)
plt.title("Temperatura por Dia ")
plt.xlabel("Dias")
plt.ylabel("Temperatura (°C)")
plt.show()

# %%
# 🔹 Gráfico 3
plt.figure()
plt.fill_between(dias, temperaturas)
plt.title("Distribuição das Temperaturas")
plt.xlabel("Dias")
plt.ylabel("Temperatura (°C)")
plt.show()
